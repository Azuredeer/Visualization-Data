# %% [markdown]
# <a href="https://colab.research.google.com/github/Azuredeer/Visualisasi-Data/blob/main/2008107010029_Yoan_Rifqi_Candra_Tugas_2_Praktikum_Visualisasi_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tugas 2 Praktikum Visualisasi Data
#
# Nama         : Yoan Rifqi Candra
# NIM          : 2008107010029
# MK           : Visualisasi Data
# Dataset      : Tourist Arrivals In India 2001-2015

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('trst1.csv',
                 skipfooter=2)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %% [markdown]
# ## 1. EXPLATORY DATA ANALYSIS
#
# Dataset Tourist Arrival in India merupakan dataset yang menampilkan data sejumlah turis yang berkunjung ke India dalam kurun waktu dari 2001 hingga 2015

# %%
df.head()
# Out:
#   Name of Countries    2001    2002    2003    2004    2005    2006    2007  \
# 0               USA  329147  348182  410803  526120  611165  696739  799062
# 1                UK  405472  387846  430917  555907  651803  734240  796191
# 2        BANGLADESH  431312  435867  454611  477446  456371  484401  480240
# 3          SRILANKA  112813  108008  109098  128711  136400  154813  204084
# 4            CANADA   88600   93598  107671  135884  157643  176567  208214
#
#      2008    2009    2010    2011     2012     2013     2014     2015
# 0  804933  827140  931292  980688  1039947  1085309  1118983  1213624
# 1  776530  769251  759494  798249   788170   809444   942562   867601
# 2  541884  468899  431962  463543   487397   524923   838860  1133879
# 3  218805  239995  266515  305853   296983   262345   301601   299513
# 4  222364  224069  242372  259017   256021   255222   268485   281306

# %%
df.tail()
# Out:
#    Name of Countries   2001   2002   2003   2004   2005   2006    2007   2008  \
# 13             ITALY  41351  37136  46908  65561  67642  79978   93540  85766
# 14     KOREA (SOUTH)  27150  29374  35584  47835  49895  70407   84583  79802
# 15          Thailand  18623  19789  26273  33442  41978  46623   50037  58065
# 16             Nepal  41135  43758  43597  53207  77024  91552   83037  78133
# 17          Pakistan  52762   2946  10364  67416  88609  83426  106283  85529
#
#      2009    2010    2011    2012    2013    2014    2015
# 13  77873   94100  100889   98743   93951   91589   88091
# 14  70485   95587  108680  109469  112619  106870  102993
# 15  67309   76617   92404  105141  117136  121362  115860
# 16  88785  104374  119131  125375  113790  126416  154720
# 17  53137   51739   48640   59846  111794   96434  124924

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name of Countries  18 non-null     object
#  1   2001               18 non-null     int64
#  2   2002               18 non-null     int64
#  3   2003               18 non-null     int64
#  4   2004               18 non-null     int64
#  5   2005               18 non-null     int64
#  6   2006               18 non-null     int64
#  7   2007               18 non-null     int64
#  8   2008               18 non-null     int64
#  9   2009               18 non-null     int64
#  10  2010               18 non-null     int64
#  11  2011               18 non-null     int64
#  12  2012               18 non-null     int64
#  13  2013               18 non-null     int64
#  14  2014               18 non-null     int64
#  15  2015               18 non-null     int64
# ...

# %%
# size of dataframe (rows, columns)
df.shape
# Out:
# (18, 16)

# %%
df.describe()
# Out:
#                 2001           2002           2003           2004  \
# count      18.000000      18.000000      18.000000      18.000000
# mean   110771.277778  105675.555556  119682.888889  152487.111111
# std    132295.374363  134751.211876  146818.100250  172622.921111
# min     13901.000000    2946.000000   10364.000000   33442.000000
# 25%     41189.000000   31314.500000   37587.250000   55082.750000
# 50%     55315.500000   55226.000000   64740.000000   82999.000000
# 75%     98975.500000   89747.000000  105166.750000  131045.750000
# max    431312.000000  435867.000000  454611.000000  555907.000000
#
#                 2005           2006           2007           2008  \
# count      18.000000      18.000000      18.000000      18.000000
# mean   170925.333333  194136.166667  219169.500000  225463.944444
# std    191518.979870  213173.436142  231411.042745  233354.754438
# min     41978.000000   46623.000000   50037.000000   58065.000000
# ...

# %%
df.isnull().sum()
# Out:
# Name of Countries    0
# 2001                 0
# 2002                 0
# 2003                 0
# 2004                 0
# 2005                 0
# 2006                 0
# 2007                 0
# 2008                 0
# 2009                 0
# 2010                 0
# 2011                 0
# 2012                 0
# 2013                 0
# 2014                 0
# 2015                 0
# dtype: int64

# %%
all(isinstance(column, str) for column in df.columns)
# Out:
# True

# %%
df.rename(columns={'Name of Countries':'Countries'}, inplace=True)
df.columns
# Out:
# Index(['Countries', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015'],
#       dtype='object')

# %%
df.set_index('Countries', inplace=True)
df.head()
# Out:
#               2001    2002    2003    2004    2005    2006    2007    2008  \
# Countries
# USA         329147  348182  410803  526120  611165  696739  799062  804933
# UK          405472  387846  430917  555907  651803  734240  796191  776530
# BANGLADESH  431312  435867  454611  477446  456371  484401  480240  541884
# SRILANKA    112813  108008  109098  128711  136400  154813  204084  218805
# CANADA       88600   93598  107671  135884  157643  176567  208214  222364
#
#               2009    2010    2011     2012     2013     2014     2015
# Countries
# USA         827140  931292  980688  1039947  1085309  1118983  1213624
# UK          769251  759494  798249   788170   809444   942562   867601
# BANGLADESH  468899  431962  463543   487397   524923   838860  1133879
# SRILANKA    239995  266515  305853   296983   262345   301601   299513
# CANADA      224069  242372  259017   256021   255222   268485   281306

# %%
df['Total'] = df.sum(axis=1)
df.head()
# Out:
#               2001    2002    2003    2004    2005    2006    2007    2008  \
# Countries
# USA         329147  348182  410803  526120  611165  696739  799062  804933
# UK          405472  387846  430917  555907  651803  734240  796191  776530
# BANGLADESH  431312  435867  454611  477446  456371  484401  480240  541884
# SRILANKA    112813  108008  109098  128711  136400  154813  204084  218805
# CANADA       88600   93598  107671  135884  157643  176567  208214  222364
#
#               2009    2010    2011     2012     2013     2014     2015  \
# Countries
# USA         827140  931292  980688  1039947  1085309  1118983  1213624
# UK          769251  759494  798249   788170   809444   942562   867601
# BANGLADESH  468899  431962  463543   487397   524923   838860  1133879
# SRILANKA    239995  266515  305853   296983   262345   301601   299513
# CANADA      224069  242372  259017   256021   255222   268485   281306
#
#                Total
# Countries
# USA         11723134
# ...

# %%
Years = list(map(str, range(2001,2015)))
Years
# Out:
# ['2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014']

# %% [markdown]
# ## 2. FILTERING

# %%
#Tahun 2002
df2002 = df['2002'].head(7)
df2002
# Out:
# Countries
# USA           348182
# UK            387846
# BANGLADESH    435867
# SRILANKA      108008
# CANADA         93598
# FRANCE         78194
# GERMANY        64891
# Name: 2002, dtype: int64

# %%
df2002 = df['2001'].head(10)
df2002
# Out:
# Countries
# USA           329147
# UK            405472
# BANGLADESH    431312
# SRILANKA      112813
# CANADA         88600
# FRANCE        102434
# GERMANY        80011
# JAPAN          80634
# AUSTRALIA      52691
# MALAYSIA       57869
# Name: 2001, dtype: int64

# %% [markdown]
# ## 3. AREA PLOT

# %%
df.sort_values(['Total'], ascending=False,  axis=0, inplace=True)
df = df.head(7)

#Transpose dataframe
df = df[Years].transpose()
df.head(7)
# Out:
# Countries     USA      UK  BANGLADESH  SRILANKA  CANADA  FRANCE  GERMANY
# 2001       329147  405472      431312    112813   88600  102434    80011
# 2002       348182  387846      435867    108008   93598   78194    64891
# 2003       410803  430917      454611    109098  107671   97654    76868
# 2004       526120  555907      477446    128711  135884  131824   116679
# 2005       611165  651803      456371    136400  157643  152258   120243
# 2006       696739  734240      484401    154813  176567  175345   156808
# 2007       799062  796191      480240    204084  208214  204827   184195

# %%
df.index = df.index.map(int)
df.plot(kind='area',alpha = 0.5,stacked=False,figsize=(20,10))

plt.title('Tingkat Kedatangan Turis di India')
plt.ylabel('Jumlah turis yang berkunjung')
plt.xlabel('Tahun')

plt.show()

# %% [markdown]
# ## 4. HISTOGRAM

# %%
df['UK'].head()
# Out:
# 2001    405472
# 2002    387846
# 2003    430917
# 2004    555907
# 2005    651803
# Name: UK, dtype: int64

# %%
count, bin_edges = np.histogram(df['UK'], bins=10)

# %%
print(count)
print(bin_edges)
# Out:
# [3 0 0 1 1 0 3 5 0 1]
# [387846.  443317.6 498789.2 554260.8 609732.4 665204.  720675.6 776147.2
#  831618.8 887090.4 942562. ]

# %%
df.plot(kind='hist', figsize=(15, 5))

# add a title to the histogram
plt.title('Histogram untuk Tingkat Kedatangan Turis di India')
# add y-label
plt.ylabel('Tingkat Kedatangan Turis')
# add x-label
plt.xlabel('Jumlah Kunjungan Turis')

plt.show()

# %% [markdown]
# ## 5. BARCHART

# %%
df.plot(kind='bar',figsize=(15,5))

plt.xlabel('Tahun')
plt.ylabel('Tingkat Kedatangan Turis')
plt.title('Barchart untuk Tingkat Kedatangan Turis di India')
# Out:
# Text(0.5, 1.0, 'Barchart untuk Tingkat Kedatangan Turis di India')

# %%
df = pd.DataFrame({'Countries': ['USA', 'UK', 'Canada', 'France', 'Bangladesh'],
                   'Year': [2001, 2002, 2003, 2004, 2005]})
df.set_index('Countries', inplace=True)
print(df)
# Out:
#             Year
# Countries
# USA         2001
# UK          2002
# Canada      2003
# France      2004
# Bangladesh  2005

# %%
plot = df.plot.pie(y='Year', figsize=(5, 7))

# %%
# autopct create %, start angle represent starting point
df['Year'].plot(kind='pie',
                            figsize=(5, 6),
                            autopct='%1.1f%%', # add in percentages
                            startangle=90,     # start angle 90° (Africa)
                            shadow=True,       # add shadow      
                            )

plt.title('Barchart untuk Tingkat Kedatangan Turis di India')
plt.axis('equal') # Sets the pie chart to look like a circle.

plt.show()

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'cyan', 'pink']
explode_list = [0.1, 0, 0, 0, 0.1]
df['Year'].plot(kind='pie',
    figsize=(15, 6),
    autopct='%1.1f%%', 
    startangle=90,    
    shadow=True,       
    labels=None,         # turn off labels on pie chart
    pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
    colors=colors_list,
    explode=explode_list # add custom colors
)
                            

# scale the title up by 12% to match pctdistance
plt.title("Barchart untuk Tingkat Kedatangan Turis di India", y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=df.index, loc='upper left') 

plt.show()

# %%
df_countries = df.groupby('Countries', axis=0).sum()
df_countries
